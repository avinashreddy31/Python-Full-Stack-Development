# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashreddy31/Python-Full-Stack-Development/blob/main/arth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5+6
# Out:
# 11

# %%
x=3
y=2
x+y
# Out:
# 5

# %%
y-1
# Out:
# 1

# %%
x+4
# Out:
# 7
